# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# pytorch only takes 2d x input so we use unsqueeze to insert a dimension of size one
x = torch.unsqueeze(torch.linspace(-5,5,100), dim=1)
y = (torch.sin(x))**2

# plot
plt.scatter(x.data.numpy(),y.data.numpy())
plt.show()

# %%
class ThreeLayerNet(nn.Module):
    def __init__(self):
        super(ThreeLayerNet, self).__init__() 
        self.linear_1 = torch.nn.Linear(1, 20) 
        self.linear_2 = torch.nn.Linear(20, 20) 
        self.linear_3 = torch.nn.Linear(20, 1)
        
    
    def forward(self,x):
        x = F.relu(self.linear_1(x))
        x = F.relu(self.linear_2(x))
        x = self.linear_3(x)
        return x

net = ThreeLayerNet()
net
# Out:
# ThreeLayerNet(
#   (linear_1): Linear(in_features=1, out_features=20, bias=True)
#   (linear_2): Linear(in_features=20, out_features=20, bias=True)
#   (linear_3): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
#optimizer
optimizer = torch.optim.SGD(net.parameters(),lr=0.2)

# loss
loss_func = torch.nn.MSELoss()

plt.ion()   
plt.show()
for t in range(2000):
    prediction = net(x)
    loss = loss_func(prediction,y)
    
    optimizer.zero_grad()
    loss.backward() 
    optimizer.step()
    
    if t % 200 == 0:
        # plot and show learning process
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), prediction.data.numpy(), 'r-', lw=3)
        plt.text(0.5, 0, 'Loss=%.4f' % loss.data.numpy(), fontdict={'size': 20, 'color':  'red'})
        plt.pause(0.1)

# %%
"""
Square wave
"""
N_max = 6
n_odds = np.arange(1,N_max,2)
xs = np.arange(-6,6,0.1)
ys = []
for x in xs:
    sum_terms = []
    for n_odd in n_odds:
        frac_term = 2/(n_odd*np.pi)
        sin_term = np.sin(n_odd*x)
        sum_term = frac_term*sin_term
        sum_terms.append(sum_term)

    y = 0.5+sum(sum_terms)
    ys.append(y)

plt.scatter(xs, ys, s=9)
plt.show()

# %%
# A variant of square wave

N_max = 15 #the larger the value the steeper the transition from 0 to 1 and the more "square"
n_odds = np.arange(4,N_max,2)
xs = np.arange(-6,6,0.1)
ys = [0.5+sum(np.multiply(2/(n_odds*np.pi), np.sin(0.5*n_odds*x))) for x in xs]

plt.plot(xs, ys)
plt.show()

# %%
"""
Another variant of square wave function
"""

N_max = 15 #the larger the value the steeper the transition from 0 to 1 and the more "square"
n_odds = np.arange(6, N_max,3)
xs = np.arange(-5,5,0.01)
ys = [0.5+sum(np.multiply(1/(n_odds*np.pi), np.sin(0.5*n_odds*x))) for x in xs]

plt.plot(xs, ys)
plt.show()
